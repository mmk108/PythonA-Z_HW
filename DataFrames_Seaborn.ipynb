# %%
#Data Frames

# %%
import pandas as pd
import numpy as np

# %%
#method1. - full path to file

# %%
#grab file providing full path
stats1= pd.read_csv("/Users/mk/Files/Courses/python_a_Z/P4-Demographic-Data.csv")

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/mk/Files/Courses/python_a_Z

# %%
#Change Working Directory
os.chdir("/Users/mk/Files/Courses/python_a_Z")

# %%
print(os.getcwd())
# Out:
# /Users/mk/Files/Courses/python_a_Z

# %%
#grab file that is currently in the current working directory
stats2 = pd.read_csv("P4-Demographic-Data.csv")

# %%
stats2
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %% [raw]
# Exploring your dataset

# %%
#1. Pull up dataframe
stats2
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#2. Number of rows 
len(stats2)
# Out:
# 195

# %%
#3. see columns 
stats2.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#4. number of columns 

len(stats2.columns)
# Out:
# 5

# %%
#5. top rows 

stats2.head(5)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#6. Bottom rows
stats2.tail(5)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
pip install --upgrade numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#7. Info on columns 
stats2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats2.describe(include='all')
# Out:
#        Country Name Country Code  Birth rate  Internet users Income Group  \
# count           195          195  195.000000      195.000000          195
# unique          195          195         NaN             NaN            4
# top           Aruba          ABW         NaN             NaN  High income
# freq              1            1         NaN             NaN           67
# mean            NaN          NaN   21.469928       42.076471          NaN
# std             NaN          NaN   10.605467       29.030788          NaN
# min             NaN          NaN    7.900000        0.900000          NaN
# 25%             NaN          NaN   12.120500       14.520000          NaN
# 50%             NaN          NaN   19.680000       41.000000          NaN
# 75%             NaN          NaN   29.759500       66.225000          NaN
# max             NaN          NaN   49.661000       96.546800          NaN
#
#              MyCalc
# count    195.000000
# unique          NaN
# ...

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
np.__version__
# Out:
# '1.21.6'

# %%
stats2.head(2)
# Out:
#   Country Name Country Code  Birth rate  Internet users Income Group
# 0        Aruba          ABW      10.244            78.9  High income
# 1  Afghanistan          AFG      35.253             5.9   Low income

# %%
stats2.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats2.columns = [ 'a', 'b','c','d', 'e']

# %%
stats2.head()
# Out:
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
stats2.columns = ['Country Name', 'Country Code', 'Birth rate', 'Internet users','Income Group']

# %%
stats2
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#Subsetting DataFrames
#1.Rows
#2. Columns 
#3. Combine the two

# %%
#part 1. Rows 
stats2[0:26]
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 0                    Aruba          ABW      10.244        78.90000
# 1              Afghanistan          AFG      35.253         5.90000
# 2                   Angola          AGO      45.985        19.10000
# 3                  Albania          ALB      12.877        57.20000
# 4     United Arab Emirates          ARE      11.044        88.00000
# 5                Argentina          ARG      17.716        59.90000
# 6                  Armenia          ARM      13.308        41.90000
# 7      Antigua and Barbuda          ATG      16.447        63.40000
# 8                Australia          AUS      13.200        83.00000
# 9                  Austria          AUT       9.400        80.61880
# 10              Azerbaijan          AZE      18.300        58.70000
# 11                 Burundi          BDI      44.151         1.30000
# 12                 Belgium          BEL      11.200        82.17020
# ...

# %%
#part 1. Rows 
stats2[100:109]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 100             Libya          LBY      21.425         16.5000
# 101         St. Lucia          LCA      15.430         46.2000
# 102     Liechtenstein          LIE       9.200         93.8000
# 103         Sri Lanka          LKA      17.863         21.9000
# 104           Lesotho          LSO      28.738          5.0000
# 105         Lithuania          LTU      10.100         68.4529
# 106        Luxembourg          LUX      11.300         93.7765
# 107            Latvia          LVA      10.200         75.2344
# 108  Macao SAR, China          MAC      11.256         65.8000
#
#             Income Group
# 100  Upper middle income
# 101  Upper middle income
# 102          High income
# 103  Lower middle income
# 104  Lower middle income
# 105          High income
# 106          High income
# 107          High income
# 108          High income

# %%
stats2[:10] # same as stats2.head(10)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# ...

# %%
#reverse the dataframe
stats2[::-1]
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 194              Zimbabwe          ZWE      35.715            18.5
# 193                Zambia          ZMB      40.471            15.4
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 191          South Africa          ZAF      20.850            46.5
# 190           Yemen, Rep.          YEM      32.947            20.0
# ..                    ...          ...         ...             ...
# 4    United Arab Emirates          ARE      11.044            88.0
# 3                 Albania          ALB      12.877            57.2
# 2                  Angola          AGO      45.985            19.1
# 1             Afghanistan          AFG      35.253             5.9
# 0                   Aruba          ABW      10.244            78.9
#
#             Income Group
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ...

# %%
#EVERY 20TH ROW

# %%
#reverse the dataframe
stats2[::20]
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 0          Aruba          ABW      10.244         78.9000          High income
# 20       Belarus          BLR      12.500         54.1700  Upper middle income
# 40    Costa Rica          CRI      15.022         45.9600  Upper middle income
# 60         Gabon          GAB      30.555          9.2000  Upper middle income
# 80         India          IND      20.291         15.1000  Lower middle income
# 100        Libya          LBY      21.425         16.5000  Upper middle income
# 120   Mozambique          MOZ      39.705          5.4000           Low income
# 140       Poland          POL       9.600         62.8492          High income
# 160     Suriname          SUR      18.455         37.4000  Upper middle income
# 180      Uruguay          URY      14.374         57.6900          High income

# %%
#PART 2 : COLUMNS

# %%
stats2.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats2.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats2['Country Name'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: Country Name, dtype: object

# %%
['Country Name','Birth rate']
# Out:
# ['Country Name', 'Birth rate']

# %%
stats2[['Country Name','Birth rate']].head()
# Out:
#            Country Name  Birth rate
# 0                 Aruba      10.244
# 1           Afghanistan      35.253
# 2                Angola      45.985
# 3               Albania      12.877
# 4  United Arab Emirates      11.044

# %%
stats2[['Birth rate','Country Name']].head()
# Out:
#    Birth rate          Country Name
# 0      10.244                 Aruba
# 1      35.253           Afghanistan
# 2      45.985                Angola
# 3      12.877               Albania
# 4      11.044  United Arab Emirates

# %%
stats2['Birth rate']
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: Birth rate, Length: 195, dtype: float64

# %%
#Part3 - bring it all together

# %%
stats2[1:10][['Birth rate','Country Name']]
# Out:
#    Birth rate          Country Name
# 1      35.253           Afghanistan
# 2      45.985                Angola
# 3      12.877               Albania
# 4      11.044  United Arab Emirates
# 5      17.716             Argentina
# 6      13.308               Armenia
# 7      16.447   Antigua and Barbuda
# 8      13.200             Australia
# 9       9.400               Austria

# %%
stats2[['Birth rate','Country Name']][4:18]
# Out:
#     Birth rate          Country Name
# 4       11.044  United Arab Emirates
# 5       17.716             Argentina
# 6       13.308               Armenia
# 7       16.447   Antigua and Barbuda
# 8       13.200             Australia
# 9        9.400               Austria
# 10      18.300            Azerbaijan
# 11      44.151               Burundi
# 12      11.200               Belgium
# 13      36.440                 Benin
# 14      40.551          Burkina Faso
# 15      20.142            Bangladesh
# 16       9.200              Bulgaria
# 17      15.040               Bahrain

# %%
df1 = stats2[4:18]
df1[['Birth rate','Country Name']]
# Out:
#     Birth rate          Country Name
# 4       11.044  United Arab Emirates
# 5       17.716             Argentina
# 6       13.308               Armenia
# 7       16.447   Antigua and Barbuda
# 8       13.200             Australia
# 9        9.400               Austria
# 10      18.300            Azerbaijan
# 11      44.151               Burundi
# 12      11.200               Belgium
# 13      36.440                 Benin
# 14      40.551          Burkina Faso
# 15      20.142            Bangladesh
# 16       9.200              Bulgaria
# 17      15.040               Bahrain

# %%
#basic Operations in a Data Frame

# %%
stats2.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats2[['Country Code', 'Birth rate','Internet users']][4:8]
# Out:
#   Country Code  Birth rate  Internet users
# 4          ARE      11.044            88.0
# 5          ARG      17.716            59.9
# 6          ARM      13.308            41.9
# 7          ATG      16.447            63.4

# %%
#mathematical operations 
results = stats2['Birth rate'] * stats2['Internet users']

# %%
results.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
#add columns 
stats2['MyCalc'] = stats2['Birth rate'] * stats2['Internet users']

# %%
stats2
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group    MyCalc
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# ...

# %%
stats2.drop(labels='MyCalc', axis=1)
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats2.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats= stats2.drop(labels='MyCalc', axis=1)

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#filtering DataFrames

# %%
#filtering is about rows

# %%
stats2.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
filter = stats2['Internet users']<2
filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: Internet users, Length: 195, dtype: bool

# %%
stats2[filter]
# Out:
#      Country Name Country Code  Birth rate  Internet users  \
# 11        Burundi          BDI      44.151             1.3
# 52        Eritrea          ERI      34.800             0.9
# 55       Ethiopia          ETH      32.925             1.9
# 64         Guinea          GIN      37.337             1.6
# 117       Myanmar          MMR      18.119             1.6
# 127         Niger          NER      49.661             1.7
# 154  Sierra Leone          SLE      36.729             1.7
# 156       Somalia          SOM      43.891             1.5
# 172   Timor-Leste          TLS      35.755             1.1
#
#             Income Group   MyCalc
# 11            Low income  57.3963
# 52            Low income  31.3200
# 55            Low income  62.5575
# 64            Low income  59.7392
# 117  Lower middle income  28.9904
# 127           Low income  84.4237
# 154           Low income  62.4393
# 156           Low income  65.8365
# 172  Lower middle income  39.3305

# %%
#or
stats2[stats2['Internet users']<2]
# Out:
#      Country Name Country Code  Birth rate  Internet users  \
# 11        Burundi          BDI      44.151             1.3
# 52        Eritrea          ERI      34.800             0.9
# 55       Ethiopia          ETH      32.925             1.9
# 64         Guinea          GIN      37.337             1.6
# 117       Myanmar          MMR      18.119             1.6
# 127         Niger          NER      49.661             1.7
# 154  Sierra Leone          SLE      36.729             1.7
# 156       Somalia          SOM      43.891             1.5
# 172   Timor-Leste          TLS      35.755             1.1
#
#             Income Group   MyCalc
# 11            Low income  57.3963
# 52            Low income  31.3200
# 55            Low income  62.5575
# 64            Low income  59.7392
# 117  Lower middle income  28.9904
# 127           Low income  84.4237
# 154           Low income  62.4393
# 156           Low income  65.8365
# 172  Lower middle income  39.3305

# %%
#Practice 

filter2 =stats2['Birth rate']>40

# %%
stats2[stats2['Birth rate']>40]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 2              Angola          AGO      45.985            19.1
# 11            Burundi          BDI      44.151             1.3
# 14       Burkina Faso          BFA      40.551             9.1
# 65        Gambia, The          GMB      42.525            14.0
# 115              Mali          MLI      44.138             3.5
# 127             Niger          NER      49.661             1.7
# 128           Nigeria          NGA      40.045            38.0
# 156           Somalia          SOM      43.891             1.5
# 167              Chad          TCD      45.745             2.3
# 178            Uganda          UGA      43.474            16.2
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
#
#             Income Group     MyCalc
# 2    Upper middle income   878.3135
# 11            Low income    57.3963
# ...

# %%
#Add AND conditioning 

stats2[(stats2['Birth rate']>40) &  (stats2['Internet users']<2)]
# Out:
#     Country Name Country Code  Birth rate  Internet users Income Group  \
# 11       Burundi          BDI      44.151             1.3   Low income
# 127        Niger          NER      49.661             1.7   Low income
# 156      Somalia          SOM      43.891             1.5   Low income
#
#       MyCalc
# 11   57.3963
# 127  84.4237
# 156  65.8365

# %%
filter & filter2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Length: 195, dtype: bool

# %%
stats2[stats2["Income Group"]== "High income"]
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 0                    Aruba          ABW      10.244           78.90
# 4     United Arab Emirates          ARE      11.044           88.00
# 5                Argentina          ARG      17.716           59.90
# 7      Antigua and Barbuda          ATG      16.447           63.40
# 8                Australia          AUS      13.200           83.00
# ..                     ...          ...         ...             ...
# 174    Trinidad and Tobago          TTO      14.590           63.80
# 180                Uruguay          URY      14.374           57.69
# 181          United States          USA      12.500           84.20
# 184          Venezuela, RB          VEN      19.842           54.90
# 185  Virgin Islands (U.S.)          VIR      10.700           45.30
#
#     Income Group      MyCalc
# 0    High income   808.25160
# 4    High income   971.87200
# 5    High income  1061.18840
# 7    High income  1042.73980
# ...

# %%
#how to get unique categories
stats2["Income Group"].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
#Exercise
#Find out everything about Malta

stats2[stats2["Country Name"]== "Malta"]
# Out:
#     Country Name Country Code  Birth rate  Internet users Income Group  \
# 116        Malta          MLT         9.5         68.9138  High income
#
#        MyCalc
# 116  654.6811

# %%
##Accessing Individual Elements 
#using .at() and .iat()

# %%
stats2[2,2] # Error Why??
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (2, 2)
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
stats2.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
#.at For labels - Important even integers are treated as labels 
#.iat for integer location

# %%
stats2.iat[3,4]
# Out:
# 'Upper middle income'

# %%
stats2.iat[0,1]
# Out:
# 'ABW'

# %%
stats2.at[2,"Birth rate"]
# Out:
# 45.985

# %%
stats2.at[3,"Income Group"]
# Out:
# 'Upper middle income'

# %%
#why we need .at

# %%
sub10= stats2[::10]

# %%
sub10
# Out:
#     Country Name Country Code  Birth rate  Internet users  \
# 0          Aruba          ABW      10.244       78.900000
# 10    Azerbaijan          AZE      18.300       58.700000
# 20       Belarus          BLR      12.500       54.170000
# 30        Canada          CAN      10.900       85.800000
# 40    Costa Rica          CRI      15.022       45.960000
# 50       Ecuador          ECU      21.070       40.353684
# 60         Gabon          GAB      30.555        9.200000
# 70     Greenland          GRL      14.500       65.800000
# 80         India          IND      20.291       15.100000
# 90    Kazakhstan          KAZ      22.730       54.000000
# 100        Libya          LBY      21.425       16.500000
# 110      Moldova          MDA      12.141       45.000000
# 120   Mozambique          MOZ      39.705        5.400000
# 130  Netherlands          NLD      10.200       93.956400
# 140       Poland          POL       9.600       62.849200
# ...

# %%
sub10.iat[10,0]
# Out:
# 'Libya'

# %%
sub10.at[10,"Country Name"] # look for label 10 which is why it is a different answer
# Out:
# 'Azerbaijan'

# %% [markdown]
# ##Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
plt.rcParams['figure.figsize']=10,5

import warnings
warnings.filterwarnings("ignore")

# %%
vis1 = sns.distplot(stats2["Internet users"])

# %%
vis1 = sns.distplot(stats2["Internet users"],bins=30)

# %%
#boxplot

vis2 = sns.boxplot(data=stats2, x="Income Group", y="Birth rate")

# %%
vis3= sns.lmplot(data=stats2, x="Internet users" , y="Birth rate", fit_reg=False,\
                 hue="Income Group",size =8, aspect =1)

# %%
#keyword Arguments in python (Advanced Tutorial)

# %%
#increase marker size 
vis3= sns.lmplot(data=stats2, x="Internet users" , y="Birth rate", fit_reg=False,\
                 hue="Income Group",size =8, aspect =1, scatter_kws ={"s":300})

#scatter_kws is a dictionary that we use to increase the size
